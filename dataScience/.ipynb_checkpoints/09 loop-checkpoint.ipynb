# %% [markdown]
# #for loop
# #while loop

# %%
for i in range(1, 6):
    print("*"*i)
#while loop
count =0
while count <= 5:
    print("*" * count)
    count +=1
# Out:
# *
# **
# ***
# ****
# *****
#
# *
# **
# ***
# ****
# *****

# %%
#Example 2: Loop through list.

list = ['php','python','dotnet']
#for loop
for lang in list:
    print(lang)
#while loop
print("\n")
c=0
while c < len(list):
    print(list[c])
    c +=1;
# Out:
# php
# python
# dotnet
#
#
# php
# python
# dotnet

# %%
#Loop Control Statements
for i in range(1, 10):
    if i == 5:
        break
    print(i)
