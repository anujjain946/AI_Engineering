# %% [markdown]
# #Variable
# - A variable is a name used to store data in memory.

# %%
lang = "Python"
course_price = 1999
print(f"langvage is {lang} and Course fees {course_price}")
# Out:
# langvage is Python and Course fees 1999

# %% [markdown]
# #Data Types in Python
# - Data types define the type of value a variable can hold.

# %%
#int
int_val = 1999

# %%
#float
float_val = 1999.50

# %%
#complex number
#complex_val = 2 + 3z

# %%
#string
name = "python"

# %%
#Boolean
is_active = True

# %%
#list
#Ordered, changeable collection
courses = ["Python","Django","flask"]

# %%
#tuple (Immutable)
#Ordered, unchangeable collection
course_fees = (1999,2000,500)

# %%
#Set
#Unordered, unique elements
fees = {2000, 1999, 3000}

# %%
#dict (Dictionary)
#Key-value pairs
anj = {"course": "Python", "fees": 1990}

# %% [markdown]
# #Type Casting
# - Type casting is converting one data type into another.

# %%
type(int_val)
new_int_val = float(int_val)
type(new_int_val)
# Out:
# float

# %%
#list(), tuple(), set()
numbers = tuple([1, 2, 3])
unique  = set([1, 1, 2])
