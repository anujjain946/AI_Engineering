# %% [markdown]
# Q1:***What is Python and why is it popular?***

# %% [markdown]
# Python is a high-level, interpreted, and easy-to-read programming language.
# - It is popular because of its simple syntax, large community support, extensive libraries, and use in web development, automation, data science, machine learning, and AI.
#
# ***Example***

# %% [markdown]
# print('Hello Python')

# %% [markdown]
# Q2:***Difference between Python 2 and Python 3***

# %% [markdown]
# Python 3 is the latest and recommended version. Python 2 reached end-of-life in January 2020 and is no longer supported.
#
#
# - | Python 2               | Python 3             |
# - | ------------------------ | ---------------------- |
# - | print is a statement     | print() is a function  |
# - | Division returns integer | Division returns float |
# - | Less Unicode support     | Better Unicode support |
# - | No longer supported      | Actively supported     |

# %% [markdown]
# Q3:***What are Python data types?***

# %% [markdown]
# Data types define the type of value a variable can store.
#
# - int
# - float
# - str
# - bool
# - list
# - tuple
# - set
# - dict

# %% [markdown]
# Q4:***Difference between List, Tuple, Set, and Dictionary***

# %% [markdown]
# List used for collction of datatype.list element are ordreble and mutable.duplicate element are allow in list.it is denoted by [].
#
# -   Example:

# %%
ls = [2,3,'anuj'] 
print(ls)
# Out:
# [2, 3, 'anuj']

# %% [markdown]
# Tuple used for collction of datatype.Tuple element are ordreble and not mutable.duplicate element are allow in Tuple.it is denoted by ().
#
# -   Example:

# %%
tuple = (1,2,3,4)
print(tuple)
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# Set used for collction of datatype.Set element are not ordreble and mutable.duplicate element are not allow in Set.it is denoted by ().
#
# -   Example:
