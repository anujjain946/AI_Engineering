# %% [markdown]
# ***What is Pandas?***
# - Pandas is a powerful, open-source Python library used for data manipulation, cleaning, and analysis. It provides two main data structures:
# - Series: A one-dimensional labeled array
# - DataFrame: A two-dimensional labeled table (like an Excel sheet or SQL table)
# -

# %%
import pandas as pd

# %%
ser = pd.Series([50,60,55,70,67])
print(ser)
# Out:
# 0    50
# 1    60
# 2    55
# 3    70
# 4    67
# dtype: int64

# %%
#Series with indexing
ser = pd.Series([50,55,60,89,69],index = ['Hindi','English','Pysics','Chemistry','Math'])
print(ser)
# Out:
# Hindi        50
# English      55
# Pysics       60
# Chemistry    89
# Math         69
# dtype: int64

# %%
#Now We wll getting value with help of indexing
ser["Hindi"]
# Out:
# np.int64(50)

# %%
#DataFrame
#2D dataframe have row and colomn

data = {
    "Name": ["Anuj", "Rahul", "Amit"],
    "Age": [25, 30, 28],
    "City": ["Delhi", "Mumbai", "Pune"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age    City
# 0   Anuj   25   Delhi
# 1  Rahul   30  Mumbai
# 2   Amit   28    Pune

# %%
#df index
print(df.index)
print(df.columns)
# Out:
# RangeIndex(start=0, stop=3, step=1)
# Index(['Name', 'Age', 'City'], dtype='object')
