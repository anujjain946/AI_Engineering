# %%
import pandas as pd

# %%
#Create a dataframe from list of list
data =[['Rahul','70'],['Mohan','50'],['neha','90'],['Satendra','77'],['pooja','76']]
ds = pd.DataFrame(data,columns = ['Name','Nmber'])
print(ds)
# Out:
#        Name Nmber
# 0     Rahul    70
# 1     Mohan    50
# 2      neha    90
# 3  Satendra    77
# 4     pooja    76

# %%
#craete dataFrame from Dictionary
data = {"a":[55,67,78],"b":[89,87,78]}
ds = pd.DataFrame(data)
print(ds)
# Out:
#     a   b
# 0  55  89
# 1  67  87
# 2  78  78

# %%
#Create DataFrame from numpy
import numpy as np
arr = [[1,2],[3,4],[4,5]]
ds = pd.DataFrame(arr,columns = ['a','b'])
print(ds)
# Out:
#    a  b
# 0  1  2
# 1  3  4
# 2  4  5

# %%
#read axcel file
pd.read_excel('student_marks.xlsx')
# Out:
#     Name  Subject  Marks       Date
# 0   Anuj     Math     85 2026-03-14
# 1  Rahul  Science     90 2026-03-14
# 2   Amit  English     78 2026-03-14

# %%
#read the data from csv file
pd.read_csv('data.csv')
# Out:
#     Name  Subject  Marks        Date
# 0   Anuj     Math     85  2026-03-14
# 1  Rahul  Science     90  2026-03-14
# 2   Amit  English     78  2026-03-14

# %%
#read data from json file
dataframe = pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')
dataframe
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#EDA -: Exploratory Data Analysis
# df.head()         # First 5 rows
# df.tail()         # Last 5 rows
# df.info()         # Column info: types, non-nulls
# df.describe()     # Stats for numeric columns
# df.columns        # List of column names
# df.shape          # (rows, columns)

dataframe.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
dataframe.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
dataframe.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
dataframe.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
dataframe.shape
# Out:
# (150, 5)

# %%
#Database
import pandas as pd
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="root",
    database="book_review"
)

query = "SELECT * FROM students"

df = pd.read_sql(query, conn)

print(df)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/anaconda3/lib/python3.13/site-packages/pandas/io/sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# OperationalError: no such table: students
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[55], line 9
#       6 conn = sqlite3.connect("book_review.db")
#       8 # query run
# ----> 9 df = pd.read_sql("SELECT * FROM students", conn)
#      11 print(df)
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/io/sql.py:708, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     706 with pandasSQL_builder(con) as pandas_sql:
#     707     if isinstance(pandas_sql, SQLiteDatabase):
# --> 708         return pandas_sql.read_query(
#     709             sql,
#     710             index_col=index_col,
#     711             params=params,
#     712             coerce_float=coerce_float,
#     713             parse_dates=parse_dates,
#     714             chunksize=chunksize,
#     715             dtype_backend=dtype_backend,
#     716             dtype=dtype,
#     717         )
#     719     try:
#     720         _is_table_name = pandas_sql.has_table(sql)
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/io/sql.py:2728, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2717 def read_query(
#    2718     self,
#    2719     sql,
#    (...)   2726     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2727 ) -> DataFrame | Iterator[DataFrame]:
# -> 2728     cursor = self.execute(sql, params)
#    2729     columns = [col_desc[0] for col_desc in cursor.description]
#    2731     if chunksize is not None:
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/io/sql.py:2676, in SQLiteDatabase.execute(self, sql, params)
#    2673     raise ex from inner_exc
#    2675 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2676 raise ex from exc
#
# DatabaseError: Execution failed on sql 'SELECT * FROM students': no such table: students
