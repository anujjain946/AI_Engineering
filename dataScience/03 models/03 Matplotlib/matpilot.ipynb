# %% [markdown]
# ***What is matplotlib.pyplot?***
#
# - it's like a paintbrush for your data.
# - We usually import it as plt:
#     - import matplotlib.pyplot as plt.
# - pyplot is sub module of matplotlib.

# %% [markdown]
# ***What is plt.show()?***
# - plt.show() is used to display plot.
# - Without it, in scripts, you might not see the plot window.

# %%
#import matplotlib.pyplot
import matplotlib.pyplot as plt

plt.plot([1,2,3],[4,5,6])
plt.show()

# %%
#Sachin Tendulkar’s Runs Over Time


years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
runs =  [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]

plt.plot(years,runs)
#add xlabel
plt.xlabel("Years")
#add ylable
plt.ylabel("Runs Score")
#add title
plt.title("Sachin Tendulkar's Yearly Runs")
plt.show()

# %%
#Draw a line in a diagram from position (0,0) to position (6,250):

import numpy as np

xpoint = np.array([0,6])
ypoint = np.array([0,250])

plt.plot(xpoint,ypoint)
plt.xlabel('xPoints')
plt.ylabel('yPoints')
plt.title("line in a diagram from position (0,0) to position (6,250)")
plt.show()

# %% [markdown]
# ***Multiple Lines in One Plot***
#
# - Using Format Strings
# - Color and Line Style Arguments
# - Line Width and Layout Tweaks
# - Using Styles in Matplotlib
#     - print(plt.style.available)
# - XKCD Comic Style

# %%
# with plt.xkcd():
years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
kohli = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]
sehwag = [0, 300, 800, 1200, 1500, 1700, 1600, 1400, 1000, 0]
runs =  [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]



# plt.plot(years, kohli, 'ro--', label="Kohli")  # red circles with dashed lines
# plt.plot(years, sehwag, 'go:', label="Sehwag")  # green triangles dotted

plt.plot(years, kohli, color='orange', linestyle='--',marker='o' ,label="Kohli")
plt.plot(years, sehwag, color='green', linestyle='-.',marker='o' ,label="Sehwag")
plt.plot(years, runs, color='blue',marker='o',linewidth=2, label="Tendulkar")


plt.xlabel("Years")
plt.ylabel("Runs")
plt.title("Performence comparison")
plt.legend()
plt.grid(True) #for grid 
plt.tight_layout()  #manage the spacing
plt.show()

# %%
import matplotlib.pyplot as plt

styles = ['Solarize_Light2', 'bmh', 'classic', 'dark_background', 
 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 
 'seaborn-v0_8', 'tableau-colorblind10']

for s in styles:
    plt.style.use(s)
    plt.plot([1, 2, 3], [10, 20, 15], marker='o')
    plt.title(f"Style: {s}")
    plt.show()

# %%
import numpy as np

for i in range(50):
    plt.plot(np.random.rand(100), linewidth=1)

plt.title("Too Much Data Can Be Confusing!")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#1) ✅ Clean Professional Version
#2) ✅ Add Data Labels (हर point par runs dikhana)
import matplotlib.pyplot as plt

years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
kohli = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]
sehwag = [0, 300, 800, 1200, 1500, 1700, 1600, 1400, 1000, 0]
runs = [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]

plt.style.use("ggplot")

plt.plot(years, kohli, color='orange', linestyle='--', marker='o', linewidth=2, label="Kohli")
plt.plot(years, sehwag, color='green', linestyle='-.', marker='s', linewidth=2, label="Sehwag")
plt.plot(years, runs, color='blue', linestyle='-', marker='^', linewidth=2, label="Tendulkar")


for x, y in zip(years, kohli):
    plt.text(x, y, str(x), fontsize=8)
    plt.text(x, y + 20, str(y), fontsize=8)

for x, y in zip(years, sehwag):
    plt.text(x, y + 30, str(y), fontsize=8)

for x, y in zip(years, runs):
    plt.text(x, y + 30, str(y), fontsize=8)

plt.xlabel("Years")
plt.ylabel("Runs")
plt.title("Performance Comparison")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#3) ✅ Fill Area Under Line
years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
kohli = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]

plt.plot(years, kohli, color='orange', marker='o', linewidth=2, label="Kohli")
plt.fill_between(years, kohli, color='orange', alpha=0.3)

plt.xlabel("Years")
plt.ylabel("Runs")
plt.title("Kohli Runs Area Chart")
plt.legend()
#plt.grid(True)
#plt.tight_layout()
plt.show()

# %%
#✅ Highlight Maximum Point
years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
kohli = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]

plt.plot(years, kohli, color='orange', marker='o', linewidth=2, label="Kohli")

max_runs = max(kohli)
max_year = years[kohli.index(max_runs)]

plt.scatter(max_year, max_runs, s=150, label="Highest Score")
plt.text(max_year, max_runs + 50, f"Max: {max_runs}", fontsize=10)

plt.xlabel("Years")
plt.ylabel("Runs")
plt.title("Kohli Highest Performance")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
kohli = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]
sehwag = [0, 300, 800, 1200, 1500, 1700, 1600, 1400, 1000, 0]
runs = [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]

plt.figure(figsize=(12, 8))

plt.subplot(1, 3, 1)
plt.plot(years, kohli, color='orange', marker='o')
plt.title("Kohli")
plt.grid(True)
for x, y in zip(years, kohli):
    plt.text(x, y + 30, str(y), fontsize=8)

plt.subplot(1, 3, 2)
#plt.subplot(3, 1, 2)
plt.plot(years, sehwag, color='green', marker='s')
plt.title("Sehwag")
plt.grid(True)
for x, y in zip(years, sehwag):
    plt.text(x, y + 30, str(y), fontsize=8)

plt.subplot(1, 3, 3)
plt.plot(years, runs, color='blue', marker='^')
plt.title("Tendulkar")
plt.grid(True)
for x, y in zip(years, sehwag):
    plt.text(x, y + 30, str(y), fontsize=8)

plt.tight_layout()
plt.xticks(years, [f"{y}" for y in years])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.style.use("seaborn-v0_8")

years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
kohli = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]
sehwag = [0, 300, 800, 1200, 1500, 1700, 1600, 1400, 1000, 0]
tendulkar = [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]

plt.figure(figsize=(12, 6))

plt.plot(years, kohli, color='orange', linestyle='--', marker='o', linewidth=2, markersize=7, label="Kohli")
plt.plot(years, sehwag, color='green', linestyle='-.', marker='s', linewidth=2, markersize=7, label="Sehwag")
plt.plot(years, tendulkar, color='blue', linestyle='-', marker='^', linewidth=2, markersize=7, label="Tendulkar")

plt.xlabel("Years", fontsize=12)
plt.ylabel("Runs", fontsize=12)
plt.title("Performance Comparison of Players", fontsize=15)
plt.xticks(years, [f"{y:.0f}" for y in years])
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ***Bar Charts in Matplotlib***

# %%
#Sachin’s Yearly Runs – Vertical Bar Chart
import matplotlib.pyplot

years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
runs =  [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]

#Basic Bar Plot
plt.bar(years,runs)
plt.xlabel('years')
plt.ylabel('Runs')
plt.title('Sachin Tendulkar\'s Yearly Runs')
plt.show()

# %%
import numpy as np
 
sachin = [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]
sehwag = [0, 200, 900, 1400, 1600, 1800, 1500, 1100, 800, 0]
kohli  = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]
 
x = np.arange(len(years))  # index positions
width = 0.25

plt.bar(x - width, sachin, width=width, label="Sachin")
plt.bar(x, sehwag, width=width, label="Sehwag")
plt.bar(x + width, kohli, width=width, label="Kohli")

plt.xlabel("Year")
plt.ylabel("Runs")
plt.title("Run Comparison")
plt.xticks(x, years)  # Show actual year instead of 0,1,2,...
plt.legend()
plt.tight_layout()
plt.show()

# %%
#Horizontal Bar Charts with barh()
players = ["Sachin", "Sehwag", "Kohli", "Yuvraj"]
runs_5yrs = [500+700+1100+1500+1800, 0+200+900+1400+1600, 0+0+500+800+1100, 300+600+800+1100+900]

plt.barh(players, runs_5yrs, color="skyblue")
plt.xlabel("Total Runs in First 5 Years")
plt.title("First 5-Year Performance of Indian Batsmen")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

players = ["Sachin", "Sehwag", "Kohli"]
runs = [1500, 1200, 1800]

plt.bar(players, runs, color="skyblue")

# Add labels on top of bars
for i in range(len(players)):
    plt.text(i, runs[i] + 50, str(runs[i]), ha='center')

plt.ylabel("Runs")
plt.title("Runs Scored by Players")
plt.tight_layout()
plt.show()

# %% [markdown]
# ***Pie Charts in Matplotlib***
#
# - Setting a Style
# - Basic Pie Chart Example
# - Custom Colors
# - Add Edges and Style Slices with wedgeprops
# - Highlight a Slice Using explode
# - Add Shadows for a 3D Feel
# - Start Angle
# - Show Percentages with autopct
# - Crowded Pie Chart – Why to Avoid
# -

# %%
#import module
import matplotlib.pyplot


# Choose any style you like
plt.style.use("ggplot")


#Basic Pie Chart
explode = [0.1, 0, 0, 0]  # Only highlight Sachin's slice
labels = ["Sachin", "Sehwag", "Kohli", "Yuvraj"]
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
runs = [18000, 8000, 12000, 9500]

plt.title("Career Runs of Indian Batsmen")
#plt.pie(runs, labels=labels, colors=colors,wedgeprops={'edgecolor': 'black', 'linewidth': 2, 'linestyle': '--'})
plt.pie(runs, labels=labels, colors=colors,explode=explode,shadow=True, startangle=140,autopct='%1.1f%%')
plt.legend()
plt.show()

# %%
#Crowded Pie Chart – Why to Avoid
# Too many categories
languages = ['Python', 'Java', 'C++', 'JavaScript', 'C#', 'Ruby', 'Go', 'Rust', 'Swift', 'PHP']
usage = [30, 20, 10, 10, 7, 5, 4, 3, 2, 1]

plt.pie(usage, labels=languages, autopct='%1.1f%%', startangle=90)
plt.title("Programming Language Usage (Crowded Example)")
plt.show()

# %% [markdown]
# ***Stack Plots in Matplotlib***

# %%
import matplotlib.pyplot as plt

activities = ['Studying', 'Playing', 'Watching TV', 'Sleeping']
time_spent = [3, 2, 2, 5]  # hours in a day

colors = ['skyblue', 'lightgreen', 'gold', 'lightcoral']

plt.figure(figsize=(10,10))
plt.pie(time_spent, labels=activities, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title("After School Activities")
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
#Stack Plot
import matplotlib.pyplot as plt

days = [1, 2, 3, 4, 5, 6, 7]  # Days of the week
studying = [3, 4, 3, 5, 4, 3, 4]
playing = [2, 2, 1, 1, 2, 3, 2]
watching_tv = [2, 1, 2, 2, 1, 1, 1]
sleeping = [5, 5, 6, 5, 6, 5, 5]

labels = ['Studying', 'Playing', 'Watching TV', 'Sleeping']
colors = ['skyblue', 'lightgreen', 'gold', 'lightcoral']

plt.figure(figsize=(6,6))
plt.stackplot(days, studying, playing, watching_tv, sleeping,
              labels=labels, colors=colors, alpha=0.8)

plt.legend(loc='upper left')  # Location of the legend
plt.title('Weekly Activity Tracker')
plt.xlabel('Day')
plt.ylabel('Hours')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ***Histograms in Matplotlib***
#
# -

# %%
import matplotlib.pyplot as plt
import numpy as np

ages = [
    34, 28, 36, 45, 27, 27, 45, 37, 25, 35,
    25, 25, 32, 10, 12, 24, 19, 33, 20, 15,
    44, 27, 30, 15, 24, 31, 18, 33, 23, 27,
    23, 48, 29, 19, 38, 17, 32, 10, 16, 31,
    37, 31, 28, 26, 15, 22, 25, 40, 33, 12,
    33, 26, 23, 36, 40, 39, 21, 26, 33, 39,
    25, 28, 18, 18, 38, 43, 29, 40, 33, 23,
    33, 45, 29, 45, 3, 38, 30, 27, 30, 10,
    27, 33, 44, 24, 21, 24, 39, 33, 24, 35,
    30, 39, 22, 26, 26, 15, 32, 32, 30, 27
]

bins = [10, 20, 30, 40, 50, 60, 70]

plt.hist(ages, bins=bins, edgecolor='black')
plt.axvline(15,color='red',linestyle='--',)
plt.title('Age Distribution of YouTube Viewers')
plt.xlabel('Age Group')
plt.ylabel('Number of Viewers')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# -

# %% [markdown]
# ****Scatter Plots in Matplotlib**
#
# - Scatter plots are used to show the relationship between two variables. Let's assume we are plotting the study hours vs. exam scores for a group of students.

# %%
#1. Basic Scatter Plot

# Sample data
study_hours = [1, 2, 3, 4, 5, 6, 7, 8, 9]
exam_scores = [40, 45, 50, 55, 60, 65, 75, 85, 90]
 
plt.scatter(study_hours, exam_scores)
plt.title('Study Hours vs Exam Score')
plt.xlabel('Study Hours')
plt.grid(True, linestyle='--', alpha=0.5)
plt.ylabel('Marks')
plt.show()

# %%
#2. Adding Color and Size
# Size of points based on score (bigger score -> bigger point)
sizes = [score * 2 for score in exam_scores]
colors = ['red' if score < 60 else 'green' for score in exam_scores]

plt.scatter(study_hours, exam_scores, s=sizes, c=colors)
plt.title('Colored & Sized Scatter Plot')
plt.xlabel('Study Hours')
plt.ylabel('Exam Score')
plt.grid(True)
plt.show()

# %%
#3. Using a Colormap

import numpy as np
 
# Also works with Numpy Arrays
scores_normalized = np.array(exam_scores)
 
plt.scatter(study_hours, exam_scores, c=scores_normalized, cmap='viridis')
plt.colorbar(label='Score')
plt.title('Scatter Plot with Colormap')
plt.xlabel('Study Hours')
plt.ylabel('Exam Score')
plt.grid(True)
plt.show()

# %%
#4. Adding Annotations

plt.scatter(study_hours, exam_scores)

# Add labels
for i in range(len(study_hours)):
    plt.annotate(f'Student {i+1}', (study_hours[i], exam_scores[i]))

plt.title('Scatter Plot with Annotations')
plt.xlabel('Study Hours')
plt.ylabel('Exam Score')
plt.grid(True)
plt.show()

# %%
#5. Multiple Groups in One Plot
# Assume two groups: Class A and Class B
class_a_hours = [2, 4, 6, 8]
class_a_scores = [45, 55, 65, 85]

class_b_hours = [1, 3, 5, 7, 9]
class_b_scores = [40, 50, 60, 70, 90]

plt.scatter(class_a_hours, class_a_scores, label='Class A', color='blue')
plt.scatter(class_b_hours, class_b_scores, label='Class B', color='orange')

plt.title('Scatter Plot: Class A vs Class B')
plt.xlabel('Study Hours')
plt.ylabel('Exam Score')
plt.legend()
plt.grid(True)
plt.show()

# %%
#subplot

import matplotlib.pyplot as plt
 
# Data
x = [1, 2, 3, 4, 5]
y1 = [i * 2 for i in x]
y2 = [i ** 2 for i in x]
 
# Create a figure with 1 row and 2 columns
plt.subplot(1, 2, 1)  # (rows, cols, plot_no)
plt.plot(x, y1)
plt.title('Double of x')
 
plt.subplot(1, 2, 2)
plt.plot(x, y2)
plt.title('Square of x')
 
plt.tight_layout()
plt.show()

# %%
#Introduction to Seaborn

import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="darkgrid")  # Options: whitegrid, dark, white, ticks

# %%
import numpy as np
 
x = np.array([0, 2, 3, 4, 5, 6, 7, 8, 9 ,10, 60])
y = np.sin(x)
 
sns.lineplot(x=x, y=y)
plt.title('Beautiful Line Plot')
plt.show()
