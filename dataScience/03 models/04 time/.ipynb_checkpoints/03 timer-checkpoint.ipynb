# %%
import time

while True:
    current_time = time.strftime("%H:%M:%S")
    print(current_time, end="\r")
    time.sleep(1)
# Out:
# 22:58:26
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 6
#       4 current_time = time.strftime("%H:%M:%S")
#       5 print(current_time, end="\r")
# ----> 6 time.sleep(1)
#
# KeyboardInterrupt:
