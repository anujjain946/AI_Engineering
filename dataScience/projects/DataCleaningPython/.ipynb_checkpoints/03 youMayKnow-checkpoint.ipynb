# %%
import json

# %%
#load json data
def loadData(fileName):
    with open(fileName,'r') as file:
        return json.load(file)


        
def findPeopleMayWeKnow(user_id,data):
    user_friends = {}
    for user in data["users"]:
        
        for user_friends in user['friends']:
            user_friends[user["id"]] = set(user_friends) 

        if user_id not in user_friends:
         return []

        direct_friends = user_friends[user_id]
        suggestions = {}

        for friend in direct_friends:
            # For all friends of friend
            for mutual in user_friends[friend]:
                if mutual != user_id and mutual not in direct_friends:
                    # Count mutual friends
                    suggestions[mutual] = suggestions.get(mutual, 0) + 1
        sorted_suggestions = sorted(suggestions.items(), key=lambda x: x[1], reverse=True)
        return [user_id for user_id, _ in sorted_suggestions]
            
    
#data = loadData('messiveData.json')
#data

# Load data
data = loadData("messiveData.json")
user_id = 1  # Example: Finding suggestions for Amit
recommendations = findPeopleMayWeKnow(user_id, data)
print(f"People You May Know for User {user_id}: {recommendations}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 42
#      40 data = loadData("messiveData.json")
#      41 user_id = 1  # Example: Finding suggestions for Amit
# ---> 42 recommendations = findPeopleMayWeKnow(user_id, data)
#      43 print(f"People You May Know for User {user_id}: {recommendations}")
#
# Cell In[16], line 13, in findPeopleMayWeKnow(user_id, data)
#      10 for user in data["users"]:
#      12     for user_friends in user['friends']:
# ---> 13         user_friends[user["id"]] = set(user_friends)
#      15     if user_id not in user_friends:
#      16      return []
#
# TypeError: 'int' object is not iterable
