# %% [markdown]
# install library

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# Loading and Preparing the Data

# %%
# Load the data
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the input data
x_train = x_train / 255.0
x_test = x_test / 255.0

# One-hot encode the labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %% [markdown]
# Building a Simple Neural Network

# %%
model = Sequential([
    Flatten(input_shape=(28, 28)),     # 28x28 images to 784 input features
    Dense(128, activation='relu'),     # Hidden layer with 128 neurons
    Dense(10, activation='softmax')    # Output layer for 10 classes
])

# %% [markdown]
# Compiling the Model

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# Training the Model

# %%
model.fit(x_train, y_train, epochs=5, batch_size=32)
# Out:
# W0000 00:00:1784285162.708929   29910 cpu_allocator_impl.cc:82] Allocation of 188160000 exceeds 10% of free system memory.
# Epoch 1/5
#  941/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9022 - loss: 0.3481

# %%
Evaluating the Model

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_acc:.4f}")
