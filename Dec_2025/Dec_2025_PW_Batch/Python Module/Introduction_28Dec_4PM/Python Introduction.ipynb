# %% [markdown]
# print() function: used to display the output to the screen

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Hello")
print("World!")
# Out:
# Hello
# World!

# %%
print("Hello", end=" ")
print("World!")
# Out:
# Hello World!

# %%
print("Hello", end="-")
print("World!")
# Out:
# Hello-World!

# %%
print("Hello", "World")
# Out:
# Hello World

# %%
print("Aditya", "Riya", "Anshul", "Priya", "Sahil", sep=',')
# Out:
# Aditya,Riya,Anshul,Priya,Sahil

# %%
print("child","young-child","Mumma","Papa", sep = ',')
# Out:
# child,young-child,Mumma,Papa

# %% [markdown]
# input() function: used to accept the user input from the keyboard.

# %%
user_input = input("Enter your name:")
print("My name is:", user_input)
# Out:
# Enter your name:Priya Bhatia
# My name is: Priya Bhatia

# %% [markdown]
# Comments in Python

# %%
# this is a single-line comment
print("Hello World")
# Out:
# Hello World

# %%
'''
This is a multiline comment.
It can span multiple lines and is enclosed within triple quotes
This is useful for documenting larger sections of the code
'''

print("Hello World")
# Out:
# Hello World

# %% [markdown]
# Unpacking of variables

# %%
# assign multiple values to multiple variables
x, y, z = 10, 20, 30

print("x:", x)
print("y:", y)
print("z:", z)
# Out:
# x: 10
# y: 20
# z: 30

# %% [markdown]
# Data types in Python

# %% [markdown]
# Numbers type

# %%
x = 10 # int type
y = 3.14 # float type
z = 2 + 3j # complex type

# %%
x
# Out:
# 10

# %%
y
# Out:
# 3.14

# %%
z
# Out:
# (2+3j)

# %%
z.real
# Out:
# 2.0

# %%
z.imag
# Out:
# 3.0

# %% [markdown]
# String type

# %%
name = "Priya Bhatia"
name
# print(name)
# Out:
# 'Priya Bhatia'

# %% [markdown]
# Boolean type

# %%
is_attended = True
print(is_attended)
# Out:
# True

# %% [markdown]
# Data Structure: a way to store the data in a structured manner. for example: List, Tuples, Set, Dictionary

# %% [markdown]
# Type conversion: process of converting a value from one data type to another

# %%
a = 5
b = float(a)
print(b)
# Out:
# 5.0

# %% [markdown]
# Task: What is the main difference between displaying the values of the variable via print function vs directly.

# %%
c = str(a)
print(c)
# Out:
# 5

# %%
c
# Out:
# '5'

# %%
type(c)
# Out:
# str

# %%
type(b)
# Out:
# float

# %%
type(a)
# Out:
# int
